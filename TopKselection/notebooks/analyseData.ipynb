# %%
import pandas as pd

df = pd.read_csv("/home/imane/aaaaaa-S4/Datamining/smart_ecommerceProject/Scraping/data/products_history.csv")

print(df.head())
# Out:
#      product_id                                title             category  \
# 0  8.050316e+12                  Create Your Own Kit                  NaN
# 1  7.632646e+12  Heads Subscription for Banisher 3.0           acne scars
# 2  7.596714e+12  Confident In My Skin Shirts & Tanks             clothing
# 3  1.988428e+08                   Banish Starter Kit  Acne Scars and Acne
# 4  1.819073e+12   Replacement Heads for Banisher 3.0           acne scars
#
#   subcategory   brand  price  price_promo  price_old  discount_pct currency  \
# 0         NaN  BANISH    0.0          NaN        NaN           NaN      USD
# 1         NaN  Banish   40.0          NaN        NaN           NaN      USD
# 2         NaN  BANISH   30.0          NaN        NaN           NaN      USD
# 3         NaN  BANISH  321.0        219.0      321.0          31.8      USD
# 4         NaN  Banish  120.0          NaN        NaN           NaN      USD
#
# ...

# %%
import pandas as pd

df = pd.read_csv("/home/imane/aaaaaa-S4/Datamining/smart_ecommerceProject/TopKselection/output/top_k_products.csv")

print(df.head())
# Out:
#    rank     product_id                                              title  \
# 0     1  8853889220853                            Rêve + You Travel Spray
# 1     2  8349789815029                             You + You Travel Spray
# 2     3  9349805965557                             Glossier You Fleur Duo
# 3     4  7951271559318  Nioxin System 1 Scalp + Hair Shampoo and Condi...
# 4     5  9110245540085                        Crème de You + Glossier You
#
#     category subcategory     brand  price  price_promo  price_old  \
# 0  Fragrance     General  Glossier  114.0        97.00      114.0
# 1  Fragrance     General  Glossier  114.0        97.00      114.0
# 2  Fragrance        Lips  Glossier  114.0        88.00      114.0
# 3   Haircare     General    Nioxin  104.0        49.95      104.0
# 4  Fragrance        Lips  Glossier  127.0        92.00      127.0
#
#    discount_pct  ... is_low_stock  log_price  popularity_score  is_budget  \
# ...
