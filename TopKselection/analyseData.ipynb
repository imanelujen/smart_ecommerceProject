# %%
import pandas as pd

df = pd.read_csv("/home/imane/aaaaaa-S4/Datamining/smart_ecommerceProject/data/products_20260327_172244.csv")

print(df.head())
# Out:
#       product_id                                              title  \
# 0  6806680076490  Gymshark Interval Seamless Light Support Sport...
# 1  6806640754890      Gymshark Interval Seamless Short - Force Blue
# 2  6806686302410       Gymshark Interval Seamless Midi Tank - Black
# 3  6806681714890  Gymshark Interval Seamless Short Sleeve Crop T...
# 4  6806667329738  Gymshark Interval Seamless Midi Tank - Stealth...
#
#                  category subcategory                       brand  price  \
# 0      Womens Sports Bras         NaN  Gymshark | Be a visionary.   44.0
# 1           Womens Shorts         NaN  Gymshark | Be a visionary.   46.0
# 2  Womens Sleeveless Tops         NaN  Gymshark | Be a visionary.   46.0
# 3          Womens SS Tops         NaN  Gymshark | Be a visionary.   44.0
# 4  Womens Sleeveless Tops         NaN  Gymshark | Be a visionary.   46.0
#
#    price_promo  price_old  discount_pct currency  ...  \
# 0          NaN        NaN           NaN      USD  ...
# ...
